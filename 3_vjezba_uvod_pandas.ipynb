# %% [markdown]
# # Pandas

# %% [markdown]
# ## Tipovi podataka u Pandasu
#
# DataFrame i Series

# %% [markdown]
# Prije uporabe, potrebno je importirati biblioteku

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'
